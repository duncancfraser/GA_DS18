# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_style('white')
Theaters = pd.read_csv('../../Data/NYC_Theaters.csv')

Theaters.head()
# Out:
#                     NAME             TEL  \
# 0    45th Street Theater  (212) 352-3101
# 1    47th Street Theater  (800) 775-1617
# 2                  59E59  (212) 753-5959
# 3          Acorn Theater  (212) 279-4200
# 4  Al Hirschfeld Theater  (212) 239-6200
#
#                                                  URL              ADDRESS1  \
# 0  http://www.theatermania.com/new-york/theaters/...  354 West 45th Street
# 1  http://www.bestofoffbroadway.com/theaters/47st...  304 West 47th Street
# 2                              http://www.59e59.org/   59 East 59th Street
# 3             http://www.theatrerow.org/theacorn.htm  410 West 42nd Street
# 4  http://www.newyorkcitytheatre.com/theaters/alh...     302 W 45th Street
#
#   ADDRES2      CITY    ZIP
# 0     NaN  New York  10036
# 1     NaN  New York  10036
# 2     NaN  New York  10022
# 3     NaN  New York  10036
# 4     NaN  New York  10036

# %%
Theaters.describe()
# Out:
#                 ZIP
# count    117.000000
# mean    9957.119658
# std      941.843160
# min        0.000000
# 25%    10013.000000
# 50%    10019.000000
# 75%    10036.000000
# max    11352.000000

# %%
Theaters['ZIP'].unique()
# Out:
# array([10036, 10022, 10019, 10027, 10023, 10003, 10011, 10014, 10012,
#        10009, 10016, 10013, 10001, 10002, 10024, 10038, 10028, 11352,
#        10025, 11101, 10018,     0])

# %%
Theaters['NAME'].count()
# Out:
# 117

# %%
bike_slice = pd.read_csv('../../Data/NYC/bike_may_sep13.csv')

print bike_slice.head()
print bike_slice.describe()
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  5/27/2013                                               9767
# 1  5/28/2013                                               5215
# 2  5/29/2013                                              10981
# 3  5/30/2013                                               9850
# 4  5/31/2013                                               9253
#
#    Cumulative trips (since launch):  \
# 0                              9767
# 1                             14982
# 2                             25963
# 3                             35813
# 4                             45066
#
#    Miles traveled today (midnight to 11:59 pm) Miles traveled to date:  \
# 0                                       21.533                  21,533
# 1                                        8.780                  30,313
# 2                                       21.898                  52,211
# ...

# %%
noise_data = pd.read_csv('../../Data/NYC/nyc_311complaints_10to14.csv')

print noise_data.head()
print noise_data.describe()
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-17-8ec9ade378fe> in <module>()
# ----> 1 noise_data = pd.read_csv('../../Data/NYC/nyc_311complaints_10to14.csv')
#       2
#       3 print noise_data.head()
#       4 print noise_data.describe()
#
# ...

# %%
subway_geo = pd.read_csv('../../Data/NYC/nyc_subway_locations.csv')

print subway_geo.head()
print subway_geo.describe()
# Out:
#                                  URL  \
# 0  http://www.mta.info/nyct/service/
# 1  http://www.mta.info/nyct/service/
# 2  http://www.mta.info/nyct/service/
# 3  http://www.mta.info/nyct/service/
# 4  http://www.mta.info/nyct/service/
#
#                                                 NAME         LINE
# 0  Smith St & Bergen St At Ne Corner (To Manhatta...          F-G
# 1                Court St & Montague St At Sw Corner  2-3-4-5-N-R
# 2                Court St & Montague St At Sw Corner  2-3-4-5-N-R
# 3              Clinton St & Montague St At Nw Corner  2-3-4-5-N-R
# 4            Flatbush Ave & Empire Blvd At Sw Corner        B-Q-S
#                                       URL                               NAME  \
# count                                1904                               1904
# unique                                  1                               1645
# top     http://www.mta.info/nyct/service/  River Ave & 161st St At Sw Corner
# ...

# %%
health_grade = pd.read_csv('../../Data/NYC/nyc_restaurant_insp.csv')

print health_grade.head()
print health_grade.describe()
# Out:
#       CAMIS                    DBA   BORO BUILDING           STREET  ZIPCODE  \
# 0  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE    10462
# 1  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE    10462
# 2  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE    10462
# 3  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE    10462
# 4  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE    10462
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  7188924968              Bakery      02/09/2015
# 1  7188924968              Bakery      03/03/2014
# 2  7188924968              Bakery      10/10/2013
# 3  7188924968              Bakery      09/11/2013
# 4  7188924968              Bakery      09/11/2013
#
#                                               ACTION VIOLATION CODE  \
# 0    Violations were cited in the following area(s).            06C
# ...

# %%
ods = {
#'bike_may_sep13.csv': 'bike_slice',
'nyc_311complaints_10to14.csv': 'nyc_noise',
'nyc_laundromats.csv': 'nyc_laundry',
'nyc_neighbourhoods.csv': 'nyc_hoods',
'nyc_restaurant_insp.csv': 'nyc_health_gr',
'nyc_school_districts.csv': 'nyc_sch_districts',
'nyc_subway_locations.csv': 'nyc_subway',
'nyc_theaters.csv': 'nyc_movies'
}

d_loc = '../../Data/NYC/'

for i in ods:
     ods[i] = pd.read_csv(d_loc+i)

# %%
print ods
# Out:
# {'nyc_subway_locations.csv':                                     URL  \
# 0     http://www.mta.info/nyct/service/
# 1     http://www.mta.info/nyct/service/
# 2     http://www.mta.info/nyct/service/
# 3     http://www.mta.info/nyct/service/
# 4     http://www.mta.info/nyct/service/
# 5     http://www.mta.info/nyct/service/
# 6     http://www.mta.info/nyct/service/
# 7     http://www.mta.info/nyct/service/
# 8     http://www.mta.info/nyct/service/
# 9     http://www.mta.info/nyct/service/
# 10    http://www.mta.info/nyct/service/
# 11    http://www.mta.info/nyct/service/
# 12    http://www.mta.info/nyct/service/
# 13    http://www.mta.info/nyct/service/
# 14    http://www.mta.info/nyct/service/
# 15    http://www.mta.info/nyct/service/
# 16    http://www.mta.info/nyct/service/
# 17    http://www.mta.info/nyct/service/
# 18    http://www.mta.info/nyct/service/
# 19    http://www.mta.info/nyct/service/
# 20    http://www.mta.info/nyct/service/
# 21    http://www.mta.info/nyct/service/
# ...
