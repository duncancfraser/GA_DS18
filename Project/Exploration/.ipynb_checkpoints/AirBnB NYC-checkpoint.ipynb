# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_style('white')

d_loc = '../../Data/NYC/'

abnb_ds = {
'abnb_cal': 'nyc_airbnb_calendar.csv',
'abnb_alist': 'nyc_airbnb_listings_abbr.csv',
'abnb_flist': 'nyc_airbnb_listings_full.csv',
'abnb_arev': 'nyc_airbnb_reviews_abbr.csv',
'abnb_frev': 'nyc_airbnb_reviews_full.csv'
}


abnb_csv = [
'nyc_airbnb_calendar.csv',
'nyc_airbnb_listings_abbr.csv',
'nyc_airbnb_listings_full.csv',
'nyc_airbnb_reviews_abbr.csv',
'nyc_airbnb_reviews_full.csv'
]

for i in abnb_ds:
     abnb_ds[i] = pd.read_csv(d_loc+i)
        
for i in abnb_ds:
    print '-'*20
    print abnb_ds[i].head()
    print abnb_ds[i].describe()

# %%
for i in abnb_ds:
    print '-'*20
    print abnb_ds[i].head()
    print abnb_ds[i].describe()
# Out:
# --------------------
# Dataset:             id       scrape_id last_scraped  \
# 0      1069266  20150101184336   2015-01-02
# 1      1846722  20150101184336   2015-01-02
# 2      2061725  20150101184336   2015-01-02
# 3        44974  20150101184336   2015-01-03
# 4      4701675  20150101184336   2015-01-02
# 5        68914  20150101184336   2015-01-02
# 6      4832596  20150101184336   2015-01-03
# 7      2562510  20150101184336   2015-01-02
# 8      3005360  20150101184336   2015-01-03
# 9      2431607  20150101184336   2015-01-02
# 10     1322641  20150101184336   2015-01-02
# 11     4833061  20150101184336   2015-01-03
# 12      234327  20150101184336   2015-01-02
# 13     2000287  20150101184336   2015-01-02
# 14     2525956  20150101184336   2015-01-02
# 15      809929  20150101184336   2015-01-02
# 16      753622  20150101184336   2015-01-02
# 17     1781041  20150101184336   2015-01-02
# 18     4060165  20150101184336   2015-01-03
# ...

# %%
print abnb_cal.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-aa49965d39b0> in <module>()
# ----> 1 print 'abnb_cal'.head()
#
# AttributeError: 'str' object has no attribute 'head'
