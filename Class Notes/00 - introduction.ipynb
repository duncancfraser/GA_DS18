# %% [markdown]
# #Course Introduction and Python Basics
# ###January 28, 2015

# %%
some_dictionary = {
}

# %%
some_dictionary['fruits'] = ['apples', 'oranges', 'bananas', 'tomatoes']
some_dictionary['veggies'] = ['beans', 'carrots', 'kale', 'beats']

# %%
print some_dictionary['fruits']
# Out:
# ['apples', 'oranges', 'bananas', 'tomatoes']

# %%
def print_items(dictionary):
    for k,v in dictionary.iteritems():
        print '%s: %s' % (k, v,)

# %%
print_items(some_dictionary)
# Out:
# veggies: ['beans', 'carrots', 'kale', 'beats']
# fruits: ['apples', 'oranges', 'bananas', 'tomatoes']

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class  Person(object):
    def __init__(self):
        self.can_walk = True
        
class Superman(Person):
        def fly(self):
            """Returns superman flying""" # This creates a doc string that appears in help
            print 'flying!'

wilt = Person()
print wilt.can_walk

clark = Superman()
print clark.can_walk
print clark.fly()

help(clark)
# Out:
# True
# True
# flying!
# None
# Help on Superman in module __main__ object:
#
# class Superman(Person)
#  |  Method resolution order:
#  |      Superman
#  |      Person
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  fly(self)
#  |      Returns superman flying
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Person:
#  |
#  |  __init__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Person:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(pd.DataFrame)
# Out:
# Help on class DataFrame in module pandas.core.frame:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to np.arange(n) if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
#  |      Column labels to use for resulting frame. Will default to
#  |      np.arange(n) if no column labels are provided
#  |  dtype : dtype, default None
# ...

# %%
nyt = pd.read_csv("http://stat.columbia.edu/~rachel/datasets/nyt1.csv")

# %%
print nyt.dtypes
print nyt.describe()
print nyt.groupby(['Signed_In', 'Gender']).describe()
# Out:
# Age            int64
# Gender         int64
# Impressions    int64
# Clicks         int64
# Signed_In      int64
# dtype: object
#                  Age         Gender    Impressions         Clicks  \
# count  458441.000000  458441.000000  458441.000000  458441.000000
# mean       29.482551       0.367037       5.007316       0.092594
# std        23.607034       0.481997       2.239349       0.309973
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       3.000000       0.000000
# 50%        31.000000       0.000000       5.000000       0.000000
# 75%        48.000000       1.000000       6.000000       0.000000
# max       108.000000       1.000000      20.000000       4.000000
#
#            Signed_In
# count  458441.000000
# mean        0.700930
# std         0.457851
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# ...

# %%
nyt_signedin_only = nyt[nyt.Signed_In == 1]
nyt_singedin_only = nyt[nyt['Signed_In'] == 1]
nyt_signedin_only.groupby('Gender').describe()
# Out:
#                         Age         Clicks    Impressions  Signed_In
# Gender
# 0      count  153070.000000  153070.000000  153070.000000     153070
#        mean       43.423336       0.073117       5.012733          1
#        std        16.763906       0.271194       2.238426          0
#        min         7.000000       0.000000       0.000000          1
#        25%        30.000000       0.000000       3.000000          1
#        50%        42.000000       0.000000       5.000000          1
#        75%        55.000000       0.000000       6.000000          1
#        max       108.000000       3.000000      17.000000          1
# 1      count  168265.000000  168265.000000  168265.000000     168265
#        mean       40.823701       0.069991       5.008629          1
#        std        15.780505       0.266324       2.239114          0
#        min         7.000000       0.000000       0.000000          1
# ...

# %%
nyt_lessthan_30 = nyt[nyt['Age'] < 30]
nyt_lessthan_30.groupby('Gender').describe()
# Out:
#                         Age         Clicks    Impressions      Signed_In
# Gender
# 0      count  173998.000000  173998.000000  173998.000000  173998.000000
#        mean        4.773980       0.125473       5.001368       0.212025
#        std         9.414424       0.362820       2.240247       0.408744
#        min         0.000000       0.000000       0.000000       0.000000
#        25%         0.000000       0.000000       3.000000       0.000000
#        50%         0.000000       0.000000       5.000000       0.000000
#        75%         0.000000       0.000000       6.000000       0.000000
#        max        29.000000       4.000000      18.000000       1.000000
# 1      count   46584.000000   46584.000000   46584.000000   46584.000000
#        mean       21.812704       0.070604       4.986068       1.000000
#        std         4.645737       0.268680       2.242610       0.000000
#        min         7.000000       0.000000       0.000000       1.000000
# ...

# %%
nyt_lessthan_30 = nyt[nyt['Age'] < 30]
nyt_lessthan_30.Age.unique()
# Out:
# array([ 0, 16, 21, 29, 19, 23, 22, 18, 17, 27, 11, 14, 24, 26, 28, 25, 15,
#        13, 20, 10, 12,  9,  8,  7])

# %%
# Finding the first ten rows
print nyt[0:10]

# This will still return the first ten rows
print nyt.set_index('Age')[0:10]

#Since the index is positional, this will also return the first 10 rows
print nyt.ix[0:10]
# Out:
#    Age  Gender  Impressions  Clicks  Signed_In
# 0   36       0            3       0          1
# 1   73       1            3       0          1
# 2   30       0            3       0          1
# 3   49       1            3       0          1
# 4   47       1           11       0          1
# 5   47       0           11       1          1
# 6    0       0            7       1          0
# 7   46       0            5       0          1
# 8   16       0            3       0          1
# 9   52       0            4       0          1
#      Gender  Impressions  Clicks  Signed_In
# Age
# 36        0            3       0          1
# 73        1            3       0          1
# 30        0            3       0          1
# 49        1            3       0          1
# 47        1           11       0          1
# 47        0           11       1          1
# 0         0            7       1          0
# 46        0            5       0          1
# ...

# %%
nyt['column_of_ones'] = 1

def saw_ad_many_times(x):
    return 1 if x >= 6 else 0

nyt['saw_ad_many_times'] = nyt['Impressions'].apply(saw_ad_many_times)

nyt['not_signed_in'] = nyt['Signed_In'].apply(lambda x: 0 if x else 1)

nyt['not_signed_in'] = nyt.apply(lambda row: 0 if row['Signed_In'] else 1, axis=1)

# %%
nyt['Click_Thru'] = nyt['Clicks'] / nyt['Impressions']
nyt_signedin_only = nyt[nyt.Signed_In == 1]
nyt_group = nyt.groupby('Age')

print nyt_group.mean()
print nyt['Click_Thru'].mean()
print nyt_group.agg({
    'Click_Thru': 'mean',
    'Gender': 'mean'
})

print nyt[nyt.Signed_In == 1].pivot_table(values = 'column_of_ones', index='Age', columns='Gender', aggfunc='count')
# Out:
#        Gender  Impressions    Clicks  Signed_In  column_of_ones  \
# Age
# 0    0.000000     4.999657  0.142080          0               1
# 7    0.200000     5.200000  0.600000          1               1
# 8    0.800000     6.266667  0.266667          1               1
# 9    0.666667     5.520833  0.104167          1               1
# 10   0.716814     4.814159  0.168142          1               1
# 11   0.671378     5.095406  0.127208          1               1
# 12   0.658703     4.885666  0.156997          1               1
# 13   0.688385     4.995279  0.149197          1               1
# 14   0.690338     5.035506  0.133877          1               1
# 15   0.673704     4.944338  0.150480          1               1
# 16   0.695033     4.990125  0.151612          1               1
# 17   0.684290     5.060207  0.152795          1               1
# 18   0.533186     4.978060  0.084440          1               1
# 19   0.537563     5.015978  0.047934          1               1
# ...

# %%
anscombe = pd.DataFrame({
    'x' : [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
    'y1' : [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68],
    'y2' : [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74],
    'y3' : [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73],
    'x4' : [8,8,8,8,8,8,8,19,8,8,8],
    'y4' : [6.58,5.76,7.71,8.84,8.47,7.04,5.25,12.50,5.56,7.91,6.89],
})

anscombe.describe()
# Out:
#                x         x4         y1         y2         y3         y4
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   9.000000   7.500909   7.500909   7.500000   7.500909
# std     3.316625   3.316625   2.031568   2.031657   2.030424   2.030579
# min     4.000000   8.000000   4.260000   3.100000   5.390000   5.250000
# 25%     6.500000   8.000000   6.315000   6.695000   6.250000   6.170000
# 50%     9.000000   8.000000   7.580000   8.140000   7.110000   7.040000
# 75%    11.500000   8.000000   8.570000   8.950000   7.980000   8.190000
# max    14.000000  19.000000  10.840000   9.260000  12.740000  12.500000

# %%
# %pylab inline

fig = plt.figure(figsize=(6, 10))
ax1 = fig.add_subplot(3, 1, 1)
ax1.set_title('Age')
ax1.hist(nyt_signedin_only['Age'])
ax2 = fig.add_subplot(3, 1, 2)
ax2.set_title('Clicks')
ax2.hist(nyt_signedin_only['Clicks'])
ax3 = fig.add_subplot(3, 1, 3)
ax3.set_title('Impressions')
ax3.hist(nyt_signedin_only['Impressions'])
fig.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# //anaconda/lib/python2.7/site-packages/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression

nyt = nyt[np.isfinite(nyt['Click_Thru'])]
dummy_fit = DummyRegressor().fit(nyt[['Signed_In', 'Gender', 'Age']], nyt['Click_Thru'])
lm_fit = LinearRegression().fit(nyt[['Signed_In', 'Gender', 'Age']], nyt['Click_Thru'])
anscombe_fit1 = LinearRegression().fit(anscombe[['x']], anscombe['y1'])
anscombe_fit2 = LinearRegression().fit(anscombe[['x']], anscombe['y2'])
anscombe_fit3 = LinearRegression().fit(anscombe[['x']], anscombe['y3'])
anscombe_fit4 = LinearRegression().fit(anscombe[['x4']], anscombe['y4'])

# %%
print "Another point of weakness: Anscombe's Quartet has the same linear model for each group"
print anscombe_fit1.coef_, anscombe_fit1.intercept_
print anscombe_fit2.coef_, anscombe_fit2.intercept_
print anscombe_fit3.coef_, anscombe_fit3.intercept_
print anscombe_fit4.coef_, anscombe_fit4.intercept_

print
print dummy_fit.score(nyt[['Signed_In', 'Gender', 'Age']], nyt['Click_Thru'])
print lm_fit.score(nyt[['Signed_In', 'Gender', 'Age']], nyt['Click_Thru'])
# Out:
# Another point of weakness: Anscombe's Quartet has the same linear model for each group
# [ 0.50009091] 3.00009090909
# [ 0.5] 3.00090909091
# [ 0.49972727] 3.00245454545
# [ 0.49990909] 3.00172727273
#
# 0.0
# 0.0103350341897

# %%
Titanic = pd.read_csv("/Users/duncanfraser/Downloads/titanic.csv")

Titanic.describe()

Titanic.groupby('sex').describe()
# Out:
#               Unnamed: 0
# sex
# man   count   869.000000
#       mean    623.294591
#       std     354.212586
#       min       1.000000
#       25%     363.000000
#       50%     686.000000
#       75%     903.000000
#       max    1285.000000
# women count   447.000000
#       mean    726.941834
#       std     417.796007
#       min     176.000000
#       25%     287.500000
#       50%     572.000000
#       75%    1156.500000
#       max    1316.000000

# %%
Titanic.groupby('class').describe()
# Out:
#                   Unnamed: 0
# class
# 1st class count   325.000000
#           mean    163.000000
#           std      93.963645
#           min       1.000000
#           25%      82.000000
#           50%     163.000000
#           75%     244.000000
#           max     325.000000
# 2nd class count   285.000000
#           mean    468.000000
#           std      82.416625
#           min     326.000000
#           25%     397.000000
#           50%     468.000000
#           75%     539.000000
#           max     610.000000
# 3rd class count   706.000000
#           mean    963.500000
#           std     203.948932
#           min     611.000000
#           25%     787.250000
#           50%     963.500000
#           75%    1139.750000
#           max    1316.000000

# %%
Titanic.groupby(['class', 'sex']).describe()
# Out:
#                         Unnamed: 0
# class     sex
# 1st class man   count   180.000000
#                 mean     94.500000
#                 std      63.103400
#                 min       1.000000
#                 25%      45.750000
#                 50%      90.500000
#                 75%     135.250000
#                 max     324.000000
#           women count   145.000000
#                 mean    248.034483
#                 std      42.063512
#                 min     176.000000
#                 25%     212.000000
#                 50%     248.000000
#                 75%     284.000000
#                 max     325.000000
# 2nd class man   count   179.000000
#                 mean    420.715084
#                 std      64.437343
#                 min     326.000000
#                 25%     370.500000
#                 50%     415.000000
#                 75%     459.500000
#                 max     597.000000
#           women count   106.000000
# ...

# %%
Titanic_Deaths = Titanic[(Titanic.survived == 'no')]

# %%
print Titanic_Deaths
# Out:
#       Unnamed: 0      class     age    sex survived
# 57            58  1st class  adults    man       no
# 58            59  1st class  adults    man       no
# 59            60  1st class  adults    man       no
# 60            61  1st class  adults    man       no
# 61            62  1st class  adults    man       no
# 62            63  1st class  adults    man       no
# 63            64  1st class  adults    man       no
# 64            65  1st class  adults    man       no
# 65            66  1st class  adults    man       no
# 66            67  1st class  adults    man       no
# 67            68  1st class  adults    man       no
# 68            69  1st class  adults    man       no
# 69            70  1st class  adults    man       no
# 70            71  1st class  adults    man       no
# 71            72  1st class  adults    man       no
# 72            73  1st class  adults    man       no
# 73            74  1st class  adults    man       no
# ...

# %%
Titanic_Deaths.describe()
# Out:
#         Unnamed: 0
# count   817.000000
# mean    733.982864
# std     366.025801
# min      58.000000
# 25%     422.000000
# 50%     805.000000
# 75%    1009.000000
# max    1316.000000

# %%
Titanic_Deaths.groupby(['class', 'sex']).describe()
# Out:
#                         Unnamed: 0
# class     sex
# 1st class man   count   118.000000
#                 mean    116.500000
#                 std      34.207699
#                 min      58.000000
#                 25%      87.250000
#                 50%     116.500000
#                 75%     145.750000
#                 max     175.000000
#           women count     4.000000
#                 mean    317.500000
#                 std       1.290994
#                 min     316.000000
#                 25%     316.750000
#                 50%     317.500000
#                 75%     318.250000
#                 max     319.000000
# 2nd class man   count   154.000000
#                 mean    416.500000
#                 std      44.600075
#                 min     340.000000
#                 25%     378.250000
#                 50%     416.500000
#                 75%     454.750000
#                 max     493.000000
#           women count    13.000000
# ...
